# %%
#import pandas
import pandas as pd
import numpy as np

#load data
df = pd.read_table('https://raw.githubusercontent.com/PineBiotech/omicslogic/master/CellLines_15Genes_1.txt')

#Set index
df.index = df.id

#clean up extra columns
df = df.drop(['id'], axis = 1)

#preview data
df
# Out:
#                     184A1     184B5     21MT1  ...     ZR751    ZR7530     ZR75B
# id                                             ...
# ENSG00000011465  0.000000  0.454356  0.000000  ...  0.238818  1.091038  0.238818
# ENSG00000057149  2.039323  2.274744  0.774070  ...  0.000000  0.000000  0.000000
# ENSG00000065618  8.505478  9.134248  0.713914  ...  0.565594  0.111089  0.201753
# ENSG00000083720  5.199763  3.975563  3.253808  ...  3.870967  3.948192  4.185121
# ENSG00000095139  5.980138  4.938758  5.641512  ...  5.891424  5.694583  5.315063
# ENSG00000104413  5.659199  5.836266  5.356153  ...  5.664112  5.857931  5.885513
# ENSG00000105185  7.047574  6.540624  6.480210  ...  6.468328  5.937743  6.319889
# ENSG00000110917  4.524903  4.338774  5.426652  ...  5.853007  5.995917  5.795903
# ENSG00000112511  3.148846  3.973675  4.182265  ...  4.645345  4.847526  3.625118
# ENSG00000116299  0.971022  0.765309  0.546165  ...  6.009726  5.943657  5.460948
# ...

# %%
import seaborn as sns

sns.clustermap(df, figsize=(12, 7))

# %% [markdown]
# Change colors with color palletes:
#
# ```
# cmap='coolwarm'
# cmap='YlGnBu'
# cmap='Blues'
# cmap='BuPu'
# cmap='Greens'
# ```
# more on Seaborn pallettes here: [Seaborn Color Palettes](https://seaborn.pydata.org/tutorial/color_palettes.html)

# %%
sns.clustermap(df, cmap='magma', figsize=(12, 7))
